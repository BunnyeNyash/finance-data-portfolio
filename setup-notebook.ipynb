# %% [markdown]
# <a href="https://colab.research.google.com/github/BunnyeNyash/finance-data-portfolio/blob/main/setup-notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! I am ready to build my finance portfolio.")
# Out:
# Hello! I am ready to build my finance portfolio.
